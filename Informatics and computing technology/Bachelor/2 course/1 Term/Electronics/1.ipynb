# %%
import Task1
from Task1 import *

# %% [markdown]
# # Лабораторная работа по Электротехнике 1
# __Вставьте здесь свои значения и запустите__

# %%
"""Input Data"""
my.E = [-11, 7]
my.R = [407, 46, 138, 295, 241, 337, 123]

"""Data from experiments"""

"""1.1"""
my.I1 = [-19.16, 3.91, 5.87]
my.I2 = [-2.49, 18.29, 6.69]
my.I3 = [-21.65, 22.22, 12.56]

"""1.2"""
my.V = np.array([-11, -2.19, 1.52, 2.54, -4.46, -1.73, 0])

"""2"""
my.Uxx = 1.5
my.Ikz = 0.00391
my.R_exp2 = 382.74

"""3"""
my.Rn = [95, 282.83, 471, 658.5, 846, 1034, 1222]
my.I = [3.13, 2.25, 1.75, 1.44, 1.22, 1.06, 0.933]
my.U = [297.55, 635.81, 825.49, 946.31, 1030, 1090, 1140]

# %%
my._1_1()
# Out:
# Task 1.1
#    I1          I2          I3'          I3''      delta
#     -19.16,      -2.49,     -21.65,     -21.65,       0.0
#       3.91,      18.29,      22.22,       22.2,    0.0009
#       5.87,       6.69,      12.56,      12.56,       0.0
#       5.87,       6.69,      12.56,      12.56,       0.0
#     -25.03,      -9.18,     -34.21,     -34.21,       0.0
#       9.78,      24.98,      34.78,      34.76,    0.0006

# %%
my._1_2()
# Out:
# Task 1.2
#    A          B          C          D          E          F          G
#      -11.0,     -2.19,      1.52,      2.54,     -4.46,     -1.73,       0.0
#          0,       407,       295,        46,         0,       123,       138
#          0,       407,       702,       748,       748,       871,      1009

# %%
my._2()
# Out:
# Task 2
# $\displaystyle R'вх = $$\frac{Uxx}{Ikz} = $$\frac{1.5}{0.00391} = 383.6317  Ом$
# <br>
# $\displaystyle R_{R15} = $$\frac{R_{1} * R_{5}}{R_{1}+R_{5}} = 151.3688  Ом$
# <br>
# $\displaystyle R_{1345} = R_{15} + R_3 + R_4 = 584.3688$
# <br>
# $\displaystyle R_{13456} = \frac{R_{1345} \cdot R_6}{R_{1345} + R_6} = 213.7388$
# <br>
# $\displaystyle R'''_{вх} = R_{13456} + R_1 + R_6 = 382.7388$
# <br>
# R'вх      R''вх     R'''вх
# 383.6317 382.74 382.7388
# R'вх      R''вх
# 383.6317 382.74

# %%
my._3()
# Out:
# Task 3
#       3.13,      2.25,      1.75,      1.44,      1.22,      1.06,     0.933
#     297.55,    635.81,    825.49,    946.31,      1030,      1090,      1140
#   931.3315, 1430.5725, 1444.6075, 1362.6864,    1256.6,    1155.4,   1063.62
